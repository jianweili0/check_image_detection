# %% [markdown]
# # This Notebook run on Colab Pro+

# %% [markdown]
# Check GPU & Memory
# * RunTime -> GPU Type -> A100
# * RunTime -> Runtime Shape -> High-RAM

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Jul 10 17:54:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
## check back to Tesla T4
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Jul 10 17:54:55 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/
# Out:
# /content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning

# %%
# !ls
# Out:
# CEDAR_data
# pytorch-CycleGAN-and-pix2pix
# signature-classification-using-siamese-pytorch.ipynb
# signature_classification_using_siamese_pytorch_jianwei.ipynb
# SignatureCleaningCycleGAN.ipynb
# signature-image-cleaning-with-tensorflow-2-0_testing.ipynb
# testing_signature_images

# %%
## only run once
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2513, done.
# remote: Total 2513 (delta 0), reused 0 (delta 0), pack-reused 2513
# Receiving objects: 100% (2513/2513), 8.20 MiB | 16.17 MiB/s, done.
# Resolving deltas: 100% (1575/1575), done.

# %%
# !pip install -r pytorch-CycleGAN-and-pix2pix/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 55.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 83.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.2/213.2 kB 25.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
# ...
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408196 sha256=18db68d8ff273494d09640fe16c007688330f3c829a0b9a4e2b327e289eafb82
#   Stored in directory: /root/.cache/pip/wheels/42/29/49/5bed207bac4578e4d2c0c5fc0226bfd33a7e2953ea56356855
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=2e96add6d5f86f9f7d16d25313e99f30e5b3f28c64a42810454f266814a4c716
# ...

# %%
# !pip install visdom
# !pip install dominate

# %% [markdown]
# # Using Custom dataset
# Custom datasets need to be organized in a particular format
# -   Create a dataset folder under `/datasets` for custom dataset.
# -   Create subfolders `testA`, `testB`, `trainA`, and `trainB` under thr dataset's folder.
# In trainA/testA, place the clean images (domainA) and in trainB/testB, place the noisy images.

# %% [markdown]
# **After Add Noise to the training Image from CycleGan-Data_Preparation_Adding_Noise,ipynb**
#
# The train test data located at
#
# trainA_path = 'CycleGan/PrepareSignatureDatagan-sign_data_kaggle_training/trainA/'
#
# testA_path = 'CycleGan/PrepareSignatureDatagan-sign_data_kaggle_training/testA/'
#
# trainB_path = 'CycleGan/PrepareSignatureDatagan-sign_data_kaggle_training/trainB/'
#
# testB_path = 'CycleGan/PrepareSignatureDatagan-sign_data_kaggle_training/testB/'

# %%
# %pwd
# Out:
# '/content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning'

# %%
# %ls
# Out:
# CEDAR_data/
# pytorch-CycleGAN-and-pix2pix/
# signature-classification-using-siamese-pytorch.ipynb
# signature_classification_using_siamese_pytorch_jianwei.ipynb
# SignatureCleaningCycleGAN.ipynb
# signature-image-cleaning-with-tensorflow-2-0_testing.ipynb
# testing_signature_images/

# %%
# %ls /content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/PrepareSignatureData/gan-sign_data_kaggle_training/
# Out:
# testA/  testB/  trainA/  trainB/

# %%
# %cd pytorch-CycleGAN-and-pix2pix/
# Out:
# /content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/pytorch-CycleGAN-and-pix2pix

# %%
# %ls
# Out:
# checkpoints/                      datasets/        models/           results/
# CycleGAN.ipynb                    docs/            options/          scripts/
# cycle_gan_signature_clean/        environment.yml  pix2pix.ipynb     test.py
# cycle_gan_signature_clean_model/  imgs/            README.md         train.py
# data/                             LICENSE          requirements.txt  util/

# %%
import os
# if not os.path.isdir("datasets/signature_data/"):
#   os.makedirs("datasets/signature_data/")

# %%
import shutil

src_path = "/content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/PrepareSignatureData/gan-sign_data_kaggle_training/"
des_path = "/content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/pytorch-CycleGAN-and-pix2pix/datasets/signature_data/"
#shutil.copytree(src_path, des_path, dirs_exist_ok=True) only run once

# %%
def checkTotalItemFromPath(path):
  count = 0
  for root_dir, cur_dir, files in os.walk(path):
      count += len(files)
  print('file count:', count)

# %%
checkTotalItemFromPath(des_path+'/testB')
# Out:
# file count: 164

# %% [markdown]
# # Training
#
# -   `python train.py --dataroot ./datasets/dataset_name --name model_name --model cycle_gan`
#
# Change the `--dataroot` and `--name` to the custom dataset's path and model's name.
# Use `--gpu_ids 0,1,..` to train on multiple GPUs.
#
# The model can translate the image in both directions (noisy to clean and clean to noisy). For our use case, we have to translate from noisy to clean. So after training, copy the latest Generator(B) `/checkpoints/model_name/latest_net_G_B.pth`  as `latest_net_G.pth` under `/checkpoints/model_name/latest_net_G.pth`.
# Use `cp ./checkpoints/horse2zebra/latest_net_G_B.pth ./checkpoints/horse2zebra/latest_net_G.pth` (see under testing section)

# %% [markdown]
# **I recommend you to refer [here](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/docs/tips.md) and [here](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/docs/qa.md). These will helps to clear a good amount of doubts and errors. Also I recommend you to go through the issues section of the repo if you faces any errors or doubts. Legand has it that you will find the solution for your miseries there.**

# %%
# %pwd
# Out:
# '/content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/pytorch-CycleGAN-and-pix2pix'

# %%
# %ls
# Out:
# checkpoints/                      datasets/        models/           results/
# CycleGAN.ipynb                    docs/            options/          scripts/
# cycle_gan_signature_clean/        environment.yml  pix2pix.ipynb     test.py
# cycle_gan_signature_clean_model/  imgs/            README.md         train.py
# data/                             LICENSE          requirements.txt  util/

# %%
# create model directiory
if not os.path.isdir("cycle_gan_signature_clean"):
  os.makedirs("cycle_gan_signature_clean")

# %%
# !python train.py --dataroot ./datasets/signature_data/ --name cycle_gan_signature_clean --model cycle_gan
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/signature_data/    	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
# ...

# %%
# !python train.py --dataroot ./datasets/signature_data/ --name cycle_gan_signature_clean --model cycle_gan --continue_train --epoch_count 80
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: ./datasets/signature_data/    	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 80                            	[default: 1]
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
# ...

# %% [markdown]
# **Training arguments**
# By default, the model trains for 100 epochs, to train for more epochs, use --n_epochs #epoch_count. The model will be trained for (100 + epoch_count) epochs.
# To continue training after you stop the training, use --continue_train and set --epoch_count epoch_number. This will resume the training from epoch_number epoch.
# eg: --continue_train --epoch_count 110 will resume the training from epoch 110.

# %% [markdown]
# # Testing
#
# -   `python test.py --dataroot datasets/dataset_name/testA --name model_name --model test --no_dropout`
#
# Change the `--dataroot` and `--name` to be consistent with your trained model's configuration.
#
# > from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix:
# > The option --model test is used for generating results of CycleGAN only for one side. This option will automatically set --dataset_mode single, which only loads the images from one set. On the contrary, using --model cycle_gan requires loading and generating results in both directions, which is sometimes unnecessary. The results will be saved at ./results/. Use --results_dir {directory_path_to_save_result} to specify the results directory.
#
# > For your own experiments, you might want to specify --netG, --norm, --no_dropout to match the generator architecture of the trained model.

# %%
# !ls
# Out:
# checkpoints			 datasets	  models	    scripts
# CycleGAN.ipynb			 docs		  options	    test.py
# cycle_gan_signature_clean	 environment.yml  pix2pix.ipynb     train.py
# cycle_gan_signature_clean_model  imgs		  README.md	    util
# data				 LICENSE	  requirements.txt

# %%
cp ./checkpoints/cycle_gan_signature_clean/latest_net_G_B.pth ./checkpoints/cycle_gan_signature_clean/latest_net_G.pth

# %%
# !python test.py --dataroot ./datasets/signature_data/ --name cycle_gan_signature_clean --model cycle_gan
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/signature_data/    	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 3
#                      name: cycle_gan_signature_clean     	[default: experiment_name]
# ...

# %%
# !python test.py --dataroot ./datasets/signature_data/ --name cycle_gan_signature_clean --model cycle_gan --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/signature_data/    	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 3
#                      name: cycle_gan_signature_clean     	[default: experiment_name]
# ...

# %%
# cp ./checkpoints/gan_signdata_kaggle/latest_net_G_B.pth ./checkpoints/gan_signdata_kaggle/latest_net_G.pth

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/pytorch-CycleGAN-and-pix2pix'

# %%
test_image_path = "/content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/testing_signature_images"

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/pytorch-CycleGAN-and-pix2pix'

# %%
# !python test.py --dataroot ./datasets/signature_data/ --name cycle_gan_signature_clean --model cycle_gan

# %%
# !python test.py --dataroot /content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/testing_signature_images/  --name cycle_gan_signature_clean --model cycle_gan --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/testing_signature_images/	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 3
# ...

# %%
# need to check the input inference dataset with A B have the same num of files
path_A = "/content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/testing_signature_images/testA"
checkTotalItemFromPath(path_A)
# Out:
# file count: 25

# %%
path_B = "/content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/testing_signature_images/testB"
checkTotalItemFromPath(path_B)
# Out:
# file count: 25

# %%
# inference on 20230710
# !python test.py --dataroot /content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/testing_signature_images/  --name cycle_gan_signature_clean --model cycle_gan --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /content/gdrive/MyDrive/Jianwei_folder/EXL/CycleGan/SignatureCleaning/testing_signature_images/	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 3
# ...
